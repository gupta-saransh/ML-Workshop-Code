# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ipl/matches.csv')

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df[df['winner'] == 'Chennai Super Kings'][['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 1            Chennai Super Kings              Kings XI Punjab
# 7            Chennai Super Kings               Mumbai Indians
# 11         Kolkata Knight Riders          Chennai Super Kings
# 14           Chennai Super Kings  Royal Challengers Bangalore
# 27              Delhi Daredevils          Chennai Super Kings
# 31           Chennai Super Kings              Kings XI Punjab
# 43         Kolkata Knight Riders          Chennai Super Kings
# 54               Deccan Chargers          Chennai Super Kings
# 56               Kings XI Punjab          Chennai Super Kings
# 62           Chennai Super Kings  Royal Challengers Bangalore
# 77           Chennai Super Kings             Rajasthan Royals
# 81           Chennai Super Kings             Delhi Daredevils
# 84           Chennai Super Kings              Deccan Chargers
# 89           Chennai Super Kings              Kings XI Punjab
# ...

# %%
sns.countplot(x=df['winner'],data=df)
plt.pyplot.xticks(rotation='vertical')
plt.pyplot.show()

# %%
df.drop_duplicates('season',keep='last')['season','winner']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('season', 'winner')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-a827af8135dd> in <module>()
# ...
